# %%
import matplotlib.pyplot as plt
from PIL import Image

# Assuming you have two image file paths: fake_image_path and real_image_path

# Load the images
def compare(fake_path, real_path):
    fake_image = Image.open(fake_path)
    real_image = Image.open(real_path)

    # Create a figure and axes
    fig, axs = plt.subplots(1, 2)

    # Display fake image with title
    axs[0].imshow(fake_image)
    axs[0].set_title("Fake Image")

    # Display real image with title
    axs[1].imshow(real_image)
    axs[1].set_title("Real Image")

    # Remove the axis labels
    for ax in axs:
        ax.axis('off')

    # Adjust spacing between subplots
    plt.subplots_adjust(wspace=0.2)

    # Show the figure
    plt.show()

# %% [markdown]
# ### dcgan fashion

# %%
dcgan_fashion_fake = "./dcgan/fashion/dcgan-fashion-100.png"
dcgan_fashion_real = "./dcgan/fashion/dcgan-fashion-real.png"
compare(dcgan_fashion_fake, dcgan_fashion_real)

# %% [markdown]
# ### cgan fashion

# %%
cgan_fashion_fake = "./cgan/fashion/cgan-fashion-90.png"
cgan_fashion_real = "./cgan/fashion/cgan-fashion-real.png"
compare(cgan_fashion_fake, cgan_fashion_real)

# %% [markdown]
# ### cgan mnist

# %%
cgan_mnist_fake = "./cgan/mnist/cgan-mnist-28.png"
cgan_mnist_real = "./cgan/mnist/cgan-mnist-real.png"

compare(cgan_mnist_fake, cgan_mnist_real)
